# %% [markdown]
# <a href="https://colab.research.google.com/github/bgsary/cv/blob/master/Diagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Untitled Diagram.png](data:image/png;base64,...)
